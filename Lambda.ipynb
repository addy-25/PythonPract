# %%
# Out:
# hello

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition=lambda a,b:a+b
type(addition)
print(addition(5,6))
# Out:
# 11

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
numbers=[1,2,3,4,5,6]
squared=list(map(lambda x:x**2,numbers))
print(squared)
# Out:
# [1, 4, 9, 16, 25, 36]

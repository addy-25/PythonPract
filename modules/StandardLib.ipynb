# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
##random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 6
# cherry

# %%
##os -file and dir access
import os
print(os.getcwd())
# Out:
# /Users/adityasingh/ProjectsNew/PyhtonPract/modules

# %%
os.makedirs("testdir")

# %%
## high level operations

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Visulization

import json
data={"name":'adi','age':23}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))


parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "adi", "age": 23}
# <class 'str'>
# {'name': 'adi', 'age': 23}
# <class 'dict'>

# %%
##csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['aditya',24])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['aditya', '24']

# %%
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-05-15 19:28:18.151621
# 2026-05-14 19:28:18.151621

# %%
## time
import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1778853557.965966
# 1778853559.971305

# %%
## regex
import re

pattern=r'\d+'
text='there are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123

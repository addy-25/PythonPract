# %%
import math
math.sqrt(64)
# Out:
# 8.0

# %%
from  math import *

print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import numpy as np

# %%
from packages.maths import addition
addition(2,3)
# Out:
# 5
